# %%
import requests
import base64


# Replace with your actual API credentials
username = "philip.kobrich@alaya.cl"
password = "Philip1992!"
api_key= "TcxNTc5MzQxODY0Nw==BAWNxN"
# Construct the API request URL

url="https://climatologia.meteochile.gob.cl/application/servicios/getEmaResumenDiario/330113?usuario={correo}&token={api_key}".format(correo=username,api_key=api_key)

response = requests.get(url)
print(str(response.content.decode()))
# Out:
# {
#     "pais": "Chile",
#     "organismo": "Direcci\u00f3n Meteorl\u00f3gica de Chile",
#     "fechaCreacion": "22-05-2024 20:30:10",
#     "timezone": "UTC",
#     "producto": "Resumen diario de la estaci\u00f3n",
#     "status": "Informaci\u00f3n recuperada",
#     "datosEstacion": {
#         "codigoNacional": 330113,
#         "codigoOMM": "85569",
#         "codigoOACI": "",
#         "nombreEstacion": "El Paico",
#         "latitud": "-33.70639",
#         "longitud": "-71.00805",
#         "altura": "275.0",
#         "provincia": "Talagante",
#         "comuna": "El Monte",
#         "region": "Metropolitana de Santiago",
#         "numeroRegion": 13,
#         "convenio": 1
#     },
#     "datos": {
#         "atrazo": 3600,
#         "fuera": 86400,
#         "valoresMasRecientes": {
#             "codigoNacional": "330113",
#             "momento": "2024-05-22 20:15:00",
#             "temperatura": "9.12177",
#             "puntoDeRocio": "8.66771",
# ...

# %%
"""
Para feriados

https://apis.digital.gob.cl/fl/

ej :https://apis.digital.gob.cl/fl/feriados/2024
"""

import requests

print(requests.get("https://api.boostr.cl/feriados/holidays.json").content.decode())

print(requests.get("https://api.boostr.cl/feriados/holidays-2025.json").content.decode())

# requests.get("https://apis.digital.gob.cl/fl/feriados/2024/02/3")
# Out:
# {"status":"success","data":[{"date":"2024-01-01","title":"Año Nuevo","type":"Civil","inalienable":true,"extra":"Civil e Irrenunciable"},{"date":"2024-03-29","title":"Viernes Santo","type":"Religioso","inalienable":false,"extra":"Religioso"},{"date":"2024-03-30","title":"Sábado Santo","type":"Religioso","inalienable":false,"extra":"Religioso"},{"date":"2024-05-01","title":"Día Nacional del Trabajo","type":"Civil","inalienable":true,"extra":"Civil e Irrenunciable"},{"date":"2024-05-21","title":"Día de las Glorias Navales","type":"Civil","inalienable":false,"extra":"Civil"},{"date":"2024-06-09","title":"Elecciones Primarias Alcaldes y Gobernadores","type":"Civil","inalienable":false,"extra":"Civil"},{"date":"2024-06-20","title":"Día Nacional de los Pueblos Indígenas","type":"Civil","inalienable":false,"extra":"Civil"},{"date":"2024-06-29","title":"San Pedro y San Pablo","type":"Religioso","inalienable":false,"extra":"Religioso"},{"date":"2024-07-16","title":"Día de la Virgen del Carmen"
# ...

# %%
# Out:
# Error fetching climate data: 404

# %%
# Out:
# {
#     "momento": "2024-05-15 17:14:15",
#     "mensaje": "Usuario no existe"
# }
